# %% [markdown]
# # Capstone Project - The Battle of Neighborhoods (Week 1)

# %% [markdown]
# **Introduction**

# %% [markdown]
# This project aims to explore and compare neighborhoods in Toronto  for families who were forced to immigrate to Canada from different countries all over the world. Reasons for immigration are different, but choosing the right city to live in with a family and children is a difficult real-life problem.

# %% [markdown]
# **Discussion of the background - problem description:**

# %% [markdown]
# Friends of mine - a couple with a son and daughter want to immigrate to Canada and someone advised them to settle down in Toronto.
# The most important aspect for them is children. Their son is 15 years old and should attend high school, the daughter is 5 years old and should go to kindergarten.
# They also need to rent a house or apartment, which they can afford, and near high school and kindergarten, in a secure neighborhood.
# The neighborhood also needs recreation places such as parks for everyday jogging and popular outdoor activities for families.<br>
# All analysis and a final report will be targeted at all families who are decided to move to Toronto and look for a nice place to live, not only for immigrants families.

# %% [markdown]
# **Data section**

# %% [markdown]
# 1. Web scraping Toronto neighborhoods from Wikipedia https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M
# ![image.png](attachment:image.png)
# 2. Using csv file to create the dataframe with the latitude and the longitude coordinates of each neighborhood
# GeoSpatial Dataset https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/labs_v1/Geospatial_Coordinates.csv
# ![image-2.png](attachment:image-2.png)
# 3. Using Foursquare API : "https://developer.foursquare.com/" to get all the venues in each neighborhood
# ![image-3.png](attachment:image-3.png)
# 4. Using data from https://trreb.ca/index.php/market-news/market-watch for the price of housing market extraction by neighborhoods
# ![image-8.png](attachment:image-8.png)
# * district numbers in Toronto https://en.wikipedia.org/wiki/List_of_neighbourhoods_in_Toronto
# 5. Using data from https://data.torontopolice.on.ca/datasets/TorontoPS::neighbourhood-crime-rates-2020-1/about for crime statistics extraction by neighborhoods
# ![image-5.png](attachment:image-5.png)
# 6. Using data from https://www.compareschoolrankings.org/ for kindergarten/elementary and secondary school ratings by neighborhoods
# ![image-4.png](attachment:image-4.png)
# * for the exact localization of school:  https://ckan0.cf.opendata.inter.prod-toronto.ca/tr/dataset/toronto-district-school-board-locations
# 7. Using data from https://www.toronto.ca/data/parks/prd/facilities/parks/index.html for parks data extraction by neighborhoods
# ![image-6.png](attachment:image-6.png)
# * and all venus using Foursquare API

# %% [markdown]
# **Methodology section**

# %% [markdown]
# 1. Collecting data from different sources
# 2. Preparing and preprocessing data, because they are in different formats - web scraping, csv, xlsx and pdf file format
# 3. Creating a new consolidated dataset of the Neighborhoods, along with their boroughs, house prices, crime statistics, school ratings, and parks
# 4. For better understanding we will visualize some data with a Folium and Matplot library
# 5. Modeling with k-means clustering algorithm (unsupervised machine learning) to cluster the neighborhoods with best characteristics (e.g. low crime rates, good house prices, and school ratings) and present the results by plotting it on maps using Folium
